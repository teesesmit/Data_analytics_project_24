# %% [markdown]
# # Palmer Penguins Data Analysis Project
#
# This notebook contains my analysis of the famous Palmer penguins dataset by Theresa Smyth

# %% [markdown]
# ### Imports
#
# Imports of dataframes required to allow investigation of the dataset.
# Further reading on data frames:
# - [seaborn](https://www.w3schools.com/python/numpy/numpy_random_seaborn.asp)
# - [matplotlib](https://www.w3schools.com/python/matplotlib_intro.asp)
# - [numpy](https://www.w3schools.com/python/numpy/default.asp)
# - [pandas](https://www.w3schools.com/python/pandas/default.asp)

# %%
# Date frames.
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %% [markdown]
# ### Task 1
# ***

# %% [markdown]
# #### Overview of Dataset
#
# The Penguins dataset is a popular and commonly used introductory dataset in the field of data science for data exploration/visualization as an alternative to Anderson's Iris dataset. The data was collected as part of research for three penguin species observed on three islands in the Palmer Archipelago, Antarctica and is available on [on GitHub](https://allisonhorst.github.io/palmerpenguins//). It contains data on various measurements of penguins collected from three species: Adelie, Chinstrap, and Gentoo. This analysis gives an overview of the variables it contains and suggests the _types_ of variables that should be used to model them in python.

# %% [markdown]
# #### Load Data
#
# Load the palmer penguins data set from a URL

# %%
#Load the penguins dataset.
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")

# %%
# Reads in the dataset:
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# Summary of the dataframes basic information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# Clean-up of dataset
# Check for nulls or missing data 

print (df.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# Remove columns that have missing data 
#https://www.w3schools.com/python/pandas/pandas_cleaning_empty_cells.asp

df.dropna(inplace=True)

# %%
# Check to see if changes have worked
print (df.isnull().sum())
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### Task 2/3
#
# ***

# %% [markdown]
# #### Types of Variables
# Data types are important to correctly apply statistical measurements to the data and therefore correctly conclude assumptions about it. The Palmer penguins dataset consists of 344 rows and 7 columns that describe different attributes of penguins. The 7 attributes are species, island, bill length in mm, bill depth in mm, flipper length in mm, body mass in mm and sex. Two types of variables will be considered for these attributes **categorical** and **numerical**. The rationale for choosing the following [variable data types](https://www.dummies.com/article/academics-the-arts/math/statistics/types-of-statistical-data-numerical-categorical-and-ordinal-169735/) is to ensure that the data is accurately represented. This allows efficient data handling and optimization of memory usage.
#
# *    **Species**: The 3 species of penguin are Adelie, Chinstrap, and Gentoo. This variable represents [categorical data](https://pandas.pydata.org/docs/user_guide/categorical.html). The ['pandas'](https://pbpython.com/pandas_dtypes_cat.html) library can be used to represent it as a categorical variable type.
#
# *    **Island**: The island where the penguin was observed Torgersen, Biscoe, and Dream. Similar to species, the island variable is categorical, and it too can be represented as a categorical variable type using 'pandas'.
#
# *    **bill_length_mm, bill_depth_mm, flipper_length_mm and body_mass_g**:
# The length of the penguin's bill, measured in millimeters. The depth of the penguin's bill, measured in millimeters. The length of the penguin's flipper, measured in millimeters. The body mass of the penguin, measured in grams. These variables are numeric variables with continuous values. Pythons native numeric data types (e.g. float) can be used to represent these numerical variables.
#
# *    **Sex**: The sex of the penguin, denoted as Male (M) or Female (F). This variable indicates the gender of the penguin and it is a categorical variable. It can be represented as a categorical variable using 'pandas'.

# %% [markdown]
# ### Task 4
#
# ***

# %% [markdown]
# 1. Create a bar chart of a variable in the dataset.
#
# The variable chosen is 'species'. This was chosen based on the nature of the variable and the visualization techniques that best represents it. The 'species' variable is categorical, representing the different types of penguin species. A bar chart is suitable for visualizing the count or frequency of each category in a categorical variable. It allows clear visual observations for each species as each category is represented by a separate bar and allows for viewers to quickly grasp the distribution and relative importance of different categories.

# %%
#Determine the samples per species.
df ['species'].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Create a bar chart of the 'species' variable

plt.figure
sns.countplot(data=df, x='species')
plt.title('Distribution of Penguin Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The bar chart above shows that the most popular penguin is the Adelie, followed by the Gentoo with the least common being the Chinstrap species. This provides the viewer/analyst quick and clear visualization that the Chinstrap penguin is at approximately half the population of the other two species.

# %% [markdown]
# 2. Create a histogram of an appropriate variable in the dataset.
#
# The variable chosen is 'flipper_length_mm'. This was chosen based on the nature of the variable and the visualization techniques that best represents it. 'flipper_length_mm' is a numerical variable, therefore a histogram is considered a suitable choice for visualizing the distributon. Histograms provide insights into the distribution of data, including its central tendency, spread, and shape. For numerical variables like flipper length, histograms are excellent for providing valuable insights into the characteristics and patterns within the data.

# %%
# Create a histogram of the 'flipper_length_mm' variable

plt.figure
sns.histplot(data=df, x='flipper_length_mm', kde=True)
plt.title('Histogram of Flipper Length')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The graphs above show the combined distribution of Flipper Length (mm) across all three penguin species. However, it is evident that the distributions are not exhibiting the expected [normal distribution](https://www.w3schools.com/statistics/statistics_normal_distribution.php) characteristics. The curve of a normal distribution is also known as the bell curve because of the bell-shaped curve. This discrepancy is likely attributed to the fact that different penguin species exhibit distinct sizes, influencing the overall distribution.
#
# A single species will be chosen to address this issue and gain a more accurate representation of the distribution. Isolating the data to a single species will allow for better observation to the inherent characteristics and variability within that particular group. This approach allows us to explore whether the assumption of a normal distribution holds more consistently within individual species.

# %%
# Filter the dataset for Adelie penguins
adelie_penguins = df[df["species"] == "Adelie"]

# Specify the numerical variable
flipper_length_mm = adelie_penguins["flipper_length_mm"]

# Create the histogram
plt.figure
sns.histplot(data=adelie_penguins, x=flipper_length_mm, kde=True)
plt.title('Histogram of Flipper Length for Adelie Penguins')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# With the focus on a single species in this case, 'Adeile' the distribution of the numerical variable exhibit in line with expectations. By examining the shape of the histogram, we can gain insights into the typical range and variability of flipper lengths among Adelie penguins. The central peak of the histogram indicates the most common flipper length among Adelie penguins. The spread of the histogram illustrates the range of flipper lengths observed among Adelie penguins. A wider spread suggests greater variability in flipper lengths, while a narrower spread indicates more uniformity. Any outliers or unusual observations in flipper length can be identified from the histogram. These outliers may represent interesting cases that warrant further investigation.

# %% [markdown]
# ### Project
#
# ***
#
# Select two variables from the data set and provide an analysis of how correlated they are.

# %% [markdown]
# #### Correlation
#
# [Correlation](https://realpython.com/numpy-scipy-pandas-correlation-python/#correlation) analysis is a valuable tool in statistics for understanding relationships between variables, identifying patterns in data, and making predictions. Correlation refers to the statistical relationship between two variables, indicating the extent to which changes in one variable are associated with changes in another variable. It measures the strength and direction of the linear relationship between two quantitative variables, i.e. correlation help us understand how two things relate to each other, whether they tend to move together or move in opposite directions.
#
# Correlation coefficients [range](https://www.w3schools.com/python/pandas/pandas_correlations.asp) from -1 to +1. A correlation coefficient close to +1 indicates a strong positive relationship, meaning that as one variable increases, the other variable tends to increase as well. Conversely, a correlation coefficient close to -1 indicates a strong negative relationship, where one variable tends to decrease as the other variable increases. A correlation coefficient close to 0 suggests a weak or no linear relationship between the variables.
#
# The most common measure of correlation is [Pearson](https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide.php) correlation coefficient, denoted by "r". It is calculated as the covariance of the two variables divided by the product of their standard deviations.

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Calculate correlation
correlation_matrix = numeric_df.corr(method='pearson')

# Print correlation matrix
print(correlation_matrix)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
# Create scatter plot using Seaborn
sns.pairplot(df, kind='scatter', diag_kind='hist')
plt.show()

# %%
# Correlation heatmap (https://www.w3schools.com/datascience/ds_stat_correlation_matrix.asp)
#Select the columns of interest
penguins_measurements = df[["bill_length_mm", "bill_depth_mm", 
                            "flipper_length_mm", "body_mass_g"]]
# Calculate the correlation matrix
corr_matrix = penguins_measurements.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix,
            annot=True,  # Show correlation values on the heatmap
            cmap='coolwarm',  # Use a diverging color palette
            vmin=-1, vmax=1,  # Set the range of the color scale
            center=0,  # Set the center of the color scale to 0
            square=True)  # Ensure the cells are square-shaped
plt.title('Correlation Heatmap of Penguin Measurements')
plt.show()

# %% [markdown]
# The correlation heat map above indicates:
#
# - Bill Length & Flipper Length have a correlation of r=0.65. This suggests that penguins with longer bills tend to have longer flippers as these variables have a moderate strong positive correlation between them.
#
# - Bill Length & Body Mass have a correlation of r=0.59. Similar to the above, a moderately strong positive correlation is observed between bill length and body mass, indicating that larger penguins generally have longer bills.
#
# - Flipper Length & Body Mass have a correlation of r=0.87. There is a strong positive correlation present, indicating that flipper length is a good predictor of body mass or vice versa.
#
# - Bill Depth & Body Mass have a correlation of r=-0.47. There is a moderate negative correlation between bill depth and body mass, suggesting that penguins with deeper bills are likely to have a lower body mass.
#
# - Bill Length & Bill Depth have a correlation of r=-0.23. There is a weak negative correlation, suggesting that they are not significantly related.
#
# - Bill Depth & Flipper Length have a correlation of r=0.49. Similar to bill depth and body mass there is a moderate negative correlation, suggesting that deeper bills are somewhat associated with shorter flippers.
#
# The weakest correlation is between bill length and bill depth which implies that they are somewhat related but not significant. The strongest correlation is between bill length and body mass, indicating that larger penguins generally have longer bills.

# %% [markdown]
# #### Correlation between flipper length and body mass

# %%
# Calculate the correlation coefficient between flipper length and body mass
correlation = df['flipper_length_mm'].corr(df['body_mass_g'])

print(f"The correlation coefficient between flipper length and body mass is: {correlation:.2f}")
# Out:
# The correlation coefficient between flipper length and body mass is: 0.87

# %% [markdown]
# In summary, the analysis revealed interesting connections between penguin size attributes. It was found that flipper length and body mass are strongly related. These insights enhance our understanding of penguin biology and open doors for further research in this intriguing field.
# These findings provide a deeper understanding of how different physical attributes relate to one another in penguins, offering a deeper look into their unique adaptations for survival in their environments. This analysis serves as a stepping stone for further research and appreciation of penguin biology.

# %% [markdown]
# ***
#
# # End
